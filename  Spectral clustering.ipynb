# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Mall_Customers.csv')

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster_group
# 0                7
# 1                9
# 2                7
# ...

# %%
X=dataset.iloc[:,[3,4]].values

# %%
import numpy as np
from sklearn.cluster import SpectralClustering
import matplotlib.pyplot as plt

X, _ = make_blobs(n_samples=200, centers=2, cluster_std=1.0, random_state=0)

list1 = []

for i in range(1, 11):
    Spectral_Clustering = SpectralClustering(n_clusters=i, assign_labels='discretize', random_state=0)
    Spectral_Clustering.fit(X)
    list1.append(Spectral_Clustering.affinity_matrix_.sum())

plt.plot(range(1, 11), list1)
plt.title('Spectral Clustering')
plt.xlabel('Number of Clusters')
plt.ylabel('Affinity Matrix Sum')
plt.show()

# %%
from sklearn.cluster import SpectralClustering
SpectralClustering = SpectralClustering(n_clusters=i, assign_labels='discretize', random_state=0)
y_SpectralClustering = SpectralClustering.fit_predict(X)

# %%
y_SpectralClustering
# Out:
# array([7, 9, 7, 5, 2, 6, 3, 8, 9, 6, 9, 4, 8, 6, 9, 6, 4, 7, 7, 7, 5, 6,
#        0, 6, 2, 6, 5, 0, 9, 4, 3, 5, 7, 5, 3, 6, 8, 5, 0, 6, 3, 7, 9, 0,
#        0, 9, 6, 8, 0, 7, 4, 0, 8, 8, 9, 8, 2, 3, 9, 4, 7, 7, 3, 8, 2, 9,
#        8, 9, 0, 6, 7, 6, 4, 9, 9, 7, 1, 8, 8, 5, 0, 9, 6, 3, 8, 2, 6, 9,
#        9, 9, 0, 8, 3, 1, 9, 9, 9, 6, 0, 5, 6, 9, 0, 6, 6, 8, 6, 6, 1, 3,
#        7, 2, 0, 0, 3, 7, 4, 5, 4, 9, 0, 9, 6, 9, 4, 7, 0, 5, 5, 0, 9, 8,
#        3, 9, 8, 1, 6, 5, 1, 7, 0, 4, 0, 6, 5, 8, 6, 6, 9, 9, 5, 6, 0, 0,
#        4, 3, 6, 5, 7, 5, 5, 2, 1, 5, 5, 4, 3, 0, 8, 8, 5, 5, 7, 0, 5, 0,
#        0, 3, 7, 5, 4, 1, 9, 1, 0, 8, 7, 5, 5, 6, 9, 8, 4, 9, 1, 9, 0, 1,
#        0, 6])

# %%
supervised=dataset
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster_group
# 0                7
# 1                9
# 2                7
# ...

# %%
supervised['Cluster_group']=y_SpectralClustering
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster_group
# 0                7
# 1                9
# 2                7
# ...

# %%
supervised.to_csv('Mall_Customers.csv',index=False)

# %%
supervised=pd.DataFrame(dataset)

# %%
supervised['Cluster_group']=label

# %%
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster_group
# 0                0
# 1                0
# 2                0
# ...

# %%
import seaborn as sns
facet = sns.lmplot(data=supervised, x=supervised.columns[3], y=supervised.columns[4], hue=supervised.columns[5], 
                   fit_reg=False, legend=True, legend_out=True)
# Out:
# /Users/vidhya/anaconda3/lib/python3.11/site-packages/seaborn/regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
